# %%
import pandas as pd

# display the full contents of a column
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# __1\.__ Load the data into a DataFrame and investigate its contents. Try to print out specific columns.

# %%
# import CSV file
df = pd.read_csv('jeopardy.csv')

# %% [markdown]
# __2\.__ There’s something odd about the column names. After you figure out the problem with the column names, you may want to rename them to make your life easier the rest of the project.

# %%
# inspect df
df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                                                                                       Question  \
# 0             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3                         In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4     Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
#
#        Answer
# 0  Copernicus
# 1  Jim Thorpe
# 2     Arizona
# 3  McDonald's
# 4  John Adams

# %%
# basic stats
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show Number  216930 non-null  int64
#  1    Air Date    216930 non-null  object
#  2    Round       216930 non-null  object
#  3    Category    216930 non-null  object
#  4    Value       216930 non-null  object
#  5    Question    216930 non-null  object
#  6    Answer      216928 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 11.6+ MB

# %%
# inspect col names
df.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %% [markdown]
# As we can see via the above output almost all column names have __trailing whitespace__.
#
# One way to remove this whitespace is to just __rename the columns__.

# %%
df.rename(columns={' Air Date': 'Date',
                   ' Round': 'Round',
                   ' Category': 'Category',
                   ' Value': 'Value',
                   ' Question': 'Question',
                   ' Answer': 'Answer'},
          inplace=True)

df.columns
# Out:
# Index(['Show Number', 'Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %% [markdown]
# __3\.__ Write a function that filters the dataset for questions that contains all of the words in a list of words.
#
# For example, when the list ["King", "England"] was passed to our function, the function returned a DataFrame of 152 rows. Every row had the strings "King" and "England" somewhere in its " Question".
#
# Test your function by printing out the column containing the question of each row of the dataset.
#
# `pandas.Series.str.contains()` [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.contains.html) and a geeksforgeeks [article](https://www.geeksforgeeks.org/python-pandas-series-str-contains/).

# %%
def find_question(my_list):
    """Find questions that includes the word in the list."""

    
    new_df = df[(df['Question'].str.contains(my_list[0], na = False)) & (df['Question'].str.contains(my_list[1], na = False))]
    
    print("There are {} questions.".format(len(new_df)))
    return new_df

find_question(['King', 'England'])
# Out:
# There are 49 questions.
#         Show Number        Date             Round  \
# 4953           3003  1997-09-24  Double Jeopardy!
# 14912          2832  1996-12-17         Jeopardy!
# 21511          4650  2004-11-19         Jeopardy!
# 23810          4862  2005-11-01         Jeopardy!
# 27555          1799  1992-05-28  Double Jeopardy!
# 33294          5589  2008-12-18         Jeopardy!
# 41148          5925  2010-05-21  Double Jeopardy!
# 41357          2751  1996-07-15         Jeopardy!
# 43122          3937  2001-10-16  Double Jeopardy!
# 47814          4365  2003-07-18  Double Jeopardy!
# 49994          5499  2008-07-03         Jeopardy!
# 51115          3574  2000-03-02         Jeopardy!
# 51565          4264  2003-02-27  Double Jeopardy!
# 56600          3533  2000-01-05  Double Jeopardy!
# 57516          4299  2003-04-17  Double Jeopardy!
# 58949          6250  2011-11-18  Double Jeopardy!
# 71808          5270  2007-07-06         Jeopardy!
# 74235          2757  1996-09-03         Jeopardy!
# 77195          3656  2000-06-26         Jeopardy!
# 79457          4230  2003-01-10  Double Jeopardy!
# 80113          5827  2010-01-05         Jeopardy!
# 84639          1558  1991-05-15         Jeopardy!
# 86412          1837  1992-09-08  Double Jeopardy!
# 89710          5390  2008-02-01  Double Jeopardy!
# 111926         1331  1990-05-21         Jeopardy!
# 118809         1905  1992-12-11         Jeopardy!
# 123299         4656  2004-11-29         Jeopardy!
# 123671         5718  2009-06-17         Jeopardy!
# 125822         4042  2002-03-12  Double Jeopardy!
# 127484         1325  1990-05-11  Double Jeopardy!
# 127758         6021  2010-11-15         Jeopardy!
# 129106         4906  2006-01-02  Double Jeopardy!
# 130208         5222  2007-05-01         Jeopardy!
# 137818         3368  1999-04-07         Jeopardy!
# 143434         1882  1992-11-10  Double Jeopardy!
# 150880         4790  2005-06-03  Double Jeopardy!
# 165110         4255  2003-02-14         Jeopardy!
# 165197         6272  2011-12-20  Double Jeopardy!
# 170007         5455  2008-05-02  Double Jeopardy!
# 174055         2143  1993-12-22  Double Jeopardy!
# 175259         3055  1997-12-05  Double Jeopardy!
# 183462         3099  1998-02-05   Final Jeopardy!
# 186239         5339  2007-11-22  Double Jeopardy!
# 187651         5264  2007-06-28         Jeopardy!
# 191579         5453  2008-04-30         Jeopardy!
# 192265         6292  2012-01-17  Double Jeopardy!
# 192966         6175  2011-06-17  Double Jeopardy!
# 194516         6114  2011-03-24  Double Jeopardy!
# 200369         2937  1997-05-13         Jeopardy!
#
#                             Category   Value  \
# 4953                    "PH"UN WORDS    $200
# 14912                  WORLD HISTORY    $100
# 21511                     THE "O.C."   $1000
# 23810                  NAME THE YEAR    $400
# 27555               HISTORIC IN-LAWS    $600
# 33294            THE BAYEUX TAPESTRY    $600
# 41148                       TREATIES   $1600
# 41357                 HISTORIC NAMES    $400
# 43122                     OH, HENRY!    $400
# 47814                        POTIONS   $2000
# 49994                    REIGN DROPS   $1000
# 51115             ALL THINGS BRITISH    $200
# 51565             MUSIC APPRECIATION    $800
# 56600                 FRENCH HISTORY    $600
# 57516               THE "UN"CATEGORY   $2000
# 58949            ASSUME THE POSITION   $2000
# 71808        WHERE THERE'S A WILLIAM   $1000
# 74235                  WORLD HISTORY    $200
# 77195                        JUNE 26    $400
# 79457                     CONQUERORS    $800
# 80113                      "M" & "M"   $1000
# 84639              FILMS OF THE '90S    $200
# 86412                        ROYALTY    $400
# 89710                 "CAN"NED WORDS   $1600
# 111926                FILE UNDER "M"  $1,000
# 118809                KINGS & QUEENS    $300
# 123299                        CHAIRS    $400
# 123671          A YEAR ENDING IN '09   $1000
# 125822              PAINT IT "BLACK"  $5,000
# 127484               MEDIEVAL PEOPLE    $600
# 127758                   STATE FACTS    $600
# 129106            HISTORIC NICKNAMES   $2000
# 130208                       ROYALTY    $600
# 137818             PEOPLE IN HISTORY    $400
# 143434                           ART    $800
# 150880  20th CENTURY BRITISH HISTORY   $1200
# 165110                     HIGH COUP   $1000
# 165197           TOUCHED BY AN ANGEL   $2000
# 170007               THE SWEET 1600s   $1600
# 79457          William the Conqueror
# 80113            "the Merry Monarch"
# 84639                   John Goodman
# 86412                         Norway
# 89710                         Canute
# 111926                   Magna Carta
# 118809         William the Conqueror
# 123299            the Stone of Scone
# 123671                          1509
# 125822              the Black Prince
# 127484                       Denmark
# 127758                       Georgia
# 129106                  "Longshanks"
# 130208                     Louis XIV
# 137818                            IV
# 143434              Anthony van Dyck
# 150880              King Edward VIII
# 165110               Oliver Cromwell
# 165197                   King Philip
# 170007             William of Orange
# 174055                       William
# 175259              King Edward VIII
# 183462                        Nassau
# 186239         Richard the Lionheart
# 187651                        Nassau
# 191579                          1066
# 192265                    Edward VII
# 192966                    John Henry
# 194516                Graham Chapman
# 200369                         Wales

# %%
# test function with other words
find_question(['last', 'fish'])
# Out:
# There are 6 questions.
#         Show Number        Date             Round  \
# 45769          4197  2002-11-26         Jeopardy!
# 51428          4706  2005-02-07         Jeopardy!
# 72188          5100  2006-11-10  Double Jeopardy!
# 102887         2055  1993-07-09         Jeopardy!
# 128057         5403  2008-02-20         Jeopardy!
# 190289         3838  2001-04-18  Double Jeopardy!
#
#                                 Category  Value  \
# 45769   SOMETHING "OLD", SOMETHING "NEW"   $200
# 51428                      THE LAST KING   $800
# 72188                       SLAW & ORDER  $2000
# 102887                              FOOD   $300
# 128057                         CAFETERIA   $600
# 190289                  LET'S GET MOVING   $200
#
#                                                                                                                        Question  \
# 45769                                 This fish story of 1952 was one of the last works Hemingway published during his lifetime
# 51428   Victor Emmanuel II didn't mind being the last king of this "fishy" Italian island; he got to be the first king of Italy
# 72188                        If you're having gravlax, the last 3 letters should tell you that you're eating this 6-letter fish
# 102887                                The last name of a nursery rhyme Jack, or a fish that's so high in fat he couldn't eat it
# 128057                     Caesar salad--great!  As long as it doesn't include pieces of these small salty fish, like last time
# 190289               The Blueback, Bonefish & Barbel were the U.S. Navy's last new diesel-powered subs before the move to these
#
#                            Answer
# 45769   "The Old Man and the Sea"
# 51428                    Sardinia
# 72188                      salmon
# 102887                      Sprat
# 128057                  anchovies
# 190289              Nuclear power

# %% [markdown]
# __Codecademy's Solution__

# %%
# Filtering a dataset by a list of words
def filter_data(data, words):
  # Lowercases all words in the list of words as well as the questions. Returns true is all of the words in the list appear in the question.
  filter = lambda x: all(word.lower() in x.lower() for word in words)
  # Applies the labmda function to the Question column and returns the rows where the function returned True
  return data.loc[data["Question"].apply(filter)]

# Testing the filter function
filtered = filter_data(df, ["King", "England"])
pd.DataFrame(filtered["Question"])
# Out:
#                                                                                                       Question
# 4953                  Both England's King George V & FDR put their stamp of approval on this "King of Hobbies"
# 6337    In retaliation for Viking raids, this "Unready" king of England attacks Norse areas of the Isle of Man
# 9191                  This king of England beat the odds to trounce the French in the 1415 Battle of Agincourt
# 11710             This Scotsman, the first Stuart king of England, was called "The Wisest Fool in Christendom"
# 13454                                     It's the number that followed the last king of England named William
# ...                                                                                                        ...
# 208295      In 1066 this great-great grandson of Rollo made what some call the last Viking invasion of England
# 208742                    Dutch-born king who ruled England jointly with Mary II & is a tasty New Zealand fish
# 213870              In 1781 William Herschel discovered Uranus & initially named it after this king of England
# 216021        His nickname was "Bertie", but he used this name & number when he became king of England in 1901
# 216789      This kingdom of England grew from 2 settlements, one founded around 495 by Cerdic & his son Cynric
#
# [152 rows x 1 columns]

# %% [markdown]
# __4\.__ Test your original function with a few different sets of words to try to __find some ways your function breaks__. Edit your function so it is more robust.
#
# For example, think about __capitalization__. We probably want to find questions that contain the word `"King"` or `"king"`.
#
# You may also want to check to __make sure you don’t find rows that contain substrings of your given words__.
#
# For example, our function found a question that didn’t contain the word `"king"`, however it did contain the word `"viking"` — it found the `"king"` inside `"viking"`.
#
# Note that this also comes with some drawbacks — you would no longer find questions that contained words like `"England's"`.

# %%
import re

def find_question(my_list):
    """Find questions that includes the word in the list."""
    
    # adding whitespace before & after words to ensure that it does not return substrings
    pattern1 = '\s' + my_list[0] + '\s'
    pattern2 = '\s' + my_list[1] + '\s'
    #capitalization issue addressed using 'case=False'
    new_df = df[(df['Question'].str.contains(pat=pattern1, na = False, case=False, regex=True)) & \
     (df['Question'].str.contains(pat=pattern2, na = False, case=False, regex=True))]
    
    print("There are {} questions.".format(len(new_df)))
    return new_df

find_question(['King', 'England'])
# Out:
# There are 51 questions.
#         Show Number        Date             Round  \
# 6337           3517  1999-12-14  Double Jeopardy!
# 9191           3907  2001-09-04  Double Jeopardy!
# 13454          4726  2005-03-07         Jeopardy!
# 18076          3227  1998-09-22  Double Jeopardy!
# 19168          3109  1998-02-19         Jeopardy!
# 21511          4650  2004-11-19         Jeopardy!
# 23810          4862  2005-11-01         Jeopardy!
# 23979          4664  2004-12-09  Double Jeopardy!
# 26780          2118  1993-11-17  Double Jeopardy!
# 33174          1333  1990-05-23         Jeopardy!
# 49994          5499  2008-07-03         Jeopardy!
# 57479          4299  2003-04-17         Jeopardy!
# 58949          6250  2011-11-18  Double Jeopardy!
# 66520          5626  2009-02-09         Jeopardy!
# 72582          2754  1996-07-18  Double Jeopardy!
# 77195          3656  2000-06-26         Jeopardy!
# 78510          3169  1998-05-14  Double Jeopardy!
# 82525          2251  1994-05-23  Double Jeopardy!
# 86412          1837  1992-09-08  Double Jeopardy!
# 89710          5390  2008-02-01  Double Jeopardy!
# 90084          4871  2005-11-14         Jeopardy!
# 94425          3868  2001-05-30  Double Jeopardy!
# 95019          3662  2000-07-04  Double Jeopardy!
# 103704         2857  1997-01-21  Double Jeopardy!
# 115727         2585  1995-11-24  Double Jeopardy!
# 118809         1905  1992-12-11         Jeopardy!
# 127484         1325  1990-05-11  Double Jeopardy!
# 127758         6021  2010-11-15         Jeopardy!
# 137818         3368  1999-04-07         Jeopardy!
# 140080         3020  1997-10-17         Jeopardy!
# 140941         5557  2008-11-04  Double Jeopardy!
# 148910         3527  1999-12-28  Double Jeopardy!
# 150622         1150  1989-09-08  Double Jeopardy!
# 150880         4790  2005-06-03  Double Jeopardy!
# 151335         4289  2003-04-03         Jeopardy!
# 151746          314  1985-11-21         Jeopardy!
# 158120         4633  2004-10-27  Double Jeopardy!
# 159374         3789  2001-02-08  Double Jeopardy!
# 159378         3789  2001-02-08  Double Jeopardy!
# 167337         1312  1990-04-24  Double Jeopardy!
# 174055         2143  1993-12-22  Double Jeopardy!
# 175259         3055  1997-12-05  Double Jeopardy!
# 178590         3718  2000-11-01         Jeopardy!
# 178921         4573  2004-06-23         Jeopardy!
# 186239         5339  2007-11-22  Double Jeopardy!
# 190102         4211  2002-12-16         Jeopardy!
# 191531         5911  2010-05-03  Double Jeopardy!
# 195099         3590  2000-03-24  Double Jeopardy!
# 200369         2937  1997-05-13         Jeopardy!
# 208742         4863  2005-11-02  Double Jeopardy!
# 216021         1881  1992-11-09  Double Jeopardy!
#
#                             Category   Value  \
# 6337                             Y1K    $800
# 9191                  WON THE BATTLE    $800
# 13454          A NUMBER FROM 1 TO 10   $1000
# 18076                  WORLD HISTORY   $1000
# 19168         HISTORIC WORLD LEADERS    $300
# 21511                     THE "O.C."   $1000
# 23810                  NAME THE YEAR    $400
# 23979                 MEDIEVAL TIMES   $2000
# 26780                THE MIDDLE AGES  $1,200
# 33174                   THE CRUSADES    $200
# 49994                    REIGN DROPS   $1000
# 57479                FACTS & FIGURES    $800
# 58949            ASSUME THE POSITION   $2000
# 66520      THE FIRST MILLENNIUM A.D.   $1000
# 72582                        ROYALTY    $400
# 77195                        JUNE 26    $400
# 78510                A LONG TIME AGO    $800
# 82525                BRITISH HISTORY  $1,000
# 86412                        ROYALTY    $400
# 89710                 "CAN"NED WORDS   $1600
# 90084       THAT'S MY ROYAL NICKNAME    $400
# 94425           THE KINGS OF ENGLAND    $200
# 95019             CELEBRATING THE IV    $400
# 103704                        RULERS   $1000
# 115727                 WORLD HISTORY   $1000
# 118809                KINGS & QUEENS    $300
# 127484               MEDIEVAL PEOPLE    $600
# 127758                   STATE FACTS    $600
# 137818             PEOPLE IN HISTORY    $400
# 140080                 WORLD HISTORY    $200
# 140941          FOREIGN-BORN LEADERS   $2000
# 148910                  THE CRUSADES    $200
# 150622               BRITISH ROYALTY    $200
# 150880  20th CENTURY BRITISH HISTORY   $1200
# 151335                   LOTTO FEVER   $1000
# 151746                NURSERY RHYMES    $300
# 158120            POTENTATE POTABLES   $1200
# 159374           LONG LIVE THE KING!  $1,500
# 159378           LONG LIVE THE KING!    $800
# 167337                       ROYALTY  $2,000
# 174055               HISTORIC PEOPLE    $200
# 175259                     THE 1930s    $400
# 178590                       HISTORY    $500
# 178921                   RICHARD III    $200
# 186239              EUROPEAN HISTORY    $800
# 190102                THINK ABOUT IT    $800
# 191531        HE DIED A DEADLY DEATH    $400
# 195099              ENGLISH MONARCHS    $600
# 200369               BRITISH HISTORY    $200
# 208742                BEFORE & AFTER  $3,000
# 216021                HISTORIC NAMES   $1000
#
#                                                                                                                            Question  \
# 6337                         In retaliation for Viking raids, this "Unready" king of England attacks Norse areas of the Isle of Man
# 9191                                       This king of England beat the odds to trounce the French in the 1415 Battle of Agincourt
# 13454                                                          It's the number that followed the last king of England named William
# 18076                               In 1199 this crusader king of England was mortally wounded while besieging the castle of Chalus
# 19168                                                     He was the only king of England to have "The Great" tacked on to his name
# 21511                                                  this man and his son ruled England following the execution of King Charles I
# 216021                             His nickname was "Bertie", but he used this name & number when he became king of England in 1901
#
#                                            Answer  Float Value  Difficulty
# 6337                                     Ethelred        800.0       800.0
# 9191                                      Henry V        800.0       800.0
# 13454                                           4       1000.0      1000.0
# 18076                     Richard the Lionhearted       1000.0      1000.0
# 19168                                      Alfred        300.0       300.0
# 21511                             Oliver Cromwell       1000.0      1000.0
# 23810                                        1066        400.0       400.0
# 23979                       Aethelred the Unready       2000.0      2000.0
# 26780                                   Harold II       1200.0      1200.0
# 33174         Richard I (Richard the Lionhearted)        200.0       200.0
# 49994                                   Edward VI       1000.0      1000.0
# 57479                       William the Conqueror        800.0       800.0
# 58949                                    Henry IV       2000.0      2000.0
# 66520                                      Alfred       1000.0      1000.0
# 72582                                King Hussein        400.0       400.0
# 77195                                 Richard III        400.0       400.0
# 78510                                 Plantagenet        800.0       800.0
# 82525                                   Charles I       1000.0      1000.0
# 86412                                      Norway        400.0       400.0
# 89710                                      Canute       1600.0      1600.0
# 90084                                      Edward        400.0       400.0
# 94425                                      George        200.0       200.0
# 95019                                   George IV        400.0       400.0
# 103704                                  Henry VII       1000.0      1000.0
# 115727                      Richard the Lionheart       1000.0      1000.0
# 118809                      William the Conqueror        300.0       300.0
# 127484                                    Denmark        600.0       600.0
# 127758                                    Georgia        600.0       600.0
# 137818                                         IV        400.0       400.0
# 140080                                  Richard I        200.0       200.0
# 140941                                   James II       2000.0      2000.0
# 148910                    Richard the Lionhearted        200.0       200.0
# 150622                      William the Conqueror        200.0       200.0
# 150880                           King Edward VIII       1200.0      1200.0
# 151335                            Richard Branson       1000.0      1000.0
# 151746                              Old King Cole        300.0       300.0
# 158120                                William III       1200.0      1200.0
# 159374                                  James (I)       1500.0      1500.0
# 159378                                 Henry VIII        800.0       800.0
# 167337  Battle of Hastings (which Harold II lost)       2000.0      2000.0
# 174055                                    William        200.0       200.0
# 175259                           King Edward VIII        400.0       400.0
# 178590                    Richard the Lionhearted        500.0       500.0
# 178921                          Westminster Abbey        200.0       200.0
# 186239                      Richard the Lionheart        800.0       800.0
# 190102                                 William II        800.0       800.0
# 191531                                 Henry VIII        400.0       400.0
# 195099                                   George I        600.0       600.0
# 200369                                      Wales        200.0       200.0
# 208742                   William of Orange roughy       3000.0      3000.0
# 216021                                 Edward VII       1000.0      1000.0

# %%
find_question(['FISH', 'last'])
# Out:
# There are 2 questions.
#         Show Number        Date      Round                          Category  \
# 45769          4197  2002-11-26  Jeopardy!  SOMETHING "OLD", SOMETHING "NEW"
# 102887         2055  1993-07-09  Jeopardy!                              FOOD
#
#        Value  \
# 45769   $200
# 102887  $300
#
#                                                                                          Question  \
# 45769   This fish story of 1952 was one of the last works Hemingway published during his lifetime
# 102887  The last name of a nursery rhyme Jack, or a fish that's so high in fat he couldn't eat it
#
#                            Answer  Difficulty
# 45769   "The Old Man and the Sea"       200.0
# 102887                      Sprat       300.0

# %% [markdown]
# __5\.__ We may want to eventually __compute aggregate statistics__, like `.mean()` on the `Value` column. But right now, the values in that column are strings. __Convert the `Value` column to floats__. If you’d like to, you can create a new column with the float values.
#
# Now that you can filter the dataset of question, __use your new column that contains the float values of each question to find the “difficulty” of certain topics__. For example, what is the average value of questions that contain the word `King`?
#
# Make sure to use the dataset that contains the float values as the dataset you use in your filtering function.

# %%
# check data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show Number  216930 non-null  int64
#  1   Date         216930 non-null  object
#  2   Round        216930 non-null  object
#  3   Category     216930 non-null  object
#  4   Value        216930 non-null  object
#  5   Question     216930 non-null  object
#  6   Answer       216928 non-null  object
#  7   Float Value  216930 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 13.2+ MB

# %%
df.Value.head()
# Out:
# 0    $200
# 1    $200
# 2    $200
# 3    $200
# 4    $200
# Name: Value, dtype: object

# %%
# clean string from '$', ',' and 'None'
difficulty = [value.replace('$', "").replace(',', "").replace('None', '0')  for value in df['Value']]

# create a pandas Series
df['Difficulty'] = difficulty

# convert column to float
df['Difficulty'] = pd.to_numeric(df["Difficulty"], downcast="float")

# check dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show Number  216930 non-null  int64
#  1   Date         216930 non-null  object
#  2   Round        216930 non-null  object
#  3   Category     216930 non-null  object
#  4   Value        216930 non-null  object
#  5   Question     216930 non-null  object
#  6   Answer       216928 non-null  object
#  7   Float Value  216930 non-null  float64
#  8   Difficulty   216930 non-null  float32
# dtypes: float32(1), float64(1), int64(1), object(6)
# memory usage: 14.1+ MB

# %%
# create subset
new_df = find_question(['King', 'England'])

# calculate mean using subset
new_df['Difficulty'].mean()
# Out:
# There are 51 questions.
# 817.6470336914062

# %%
# create subset
new_dfA = find_question(['FISH', 'last'])

# calculate mean using subset
new_dfA['Difficulty'].mean()
# Out:
# There are 2 questions.
# 250.0

# %% [markdown]
# __Codecademy's Solution__

# %%
# Adding a new column. If the value of the float column is not "None",
# then we cut off the first character (which is a dollar sign),
# and replace all commas with nothing, and then cast that value to a float.
# If the answer was "None", then we just enter a 0.
df["Float Value"] = df["Value"].apply(lambda x: float(x[1:].replace(',','')) if x != "None" else 0)
df.head()
# Out:
#    Show Number        Date      Round                         Category Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                                                                                       Question  \
# 0             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3                         In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4     Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
#
#        Answer  Float Value  Difficulty
# 0  Copernicus        200.0       200.0
# 1  Jim Thorpe        200.0       200.0
# 2     Arizona        200.0       200.0
# 3  McDonald's        200.0       200.0
# 4  John Adams        200.0       200.0

# %%
# Filtering the dataset and finding the average value of those questions
filtered = filter_data(df, ["King"])
print(filtered["Float Value"].mean())
# Out:
# 771.8833850722094

# %% [markdown]
# __6\.__ Write a function that returns the __count of the unique answers to all of the questions in a dataset__.
#
# For example, after filtering the entire dataset to only questions containing the word `King`, we could then find all of the unique answers to those questions. The answer `Henry VIII` appeared 3 times and was the most common answer.

# %%
def find_question(df, string):
    """Find questions that includes the word in the list."""
    
    if len(string) == 1:
        # adding whitespace before & after words to ensure that it does not return substrings
        pattern1 = '\s' + string[0] + '\s'
        #capitalization issue addressed using 'case=False'
        new_df = df[(df['Question'].str.contains(pat=pattern1, na = False, case=False, regex=True))]
    elif len(string) == 2:
        # adding whitespace before & after words to ensure that it does not return substrings
        pattern1 = '\s' + string[0] + '\s'
        pattern2 = '\s' + string[1] + '\s'
        #capitalization issue addressed using 'case=False'
        new_df = df[(df['Question'].str.contains(pat=pattern1, na = False, case=False, regex=True)) & \
         (df['Question'].str.contains(pat=pattern2, na = False, case=False, regex=True))]
    elif len(string) == 3:
        # adding whitespace before & after words to ensure that it does not return substrings
        pattern1 = '\s' + string[0] + '\s'
        pattern2 = '\s' + string[1] + '\s'
        pattern2 = '\s' + string[2] + '\s'
        #capitalization issue addressed using 'case=False'
        new_df = df[(df['Question'].str.contains(pat=pattern1, na = False, case=False, regex=True)) & \
         (df['Question'].str.contains(pat=pattern2, na = False, case=False, regex=True)) & 
                   (df['Question'].str.contains(pat=pattern2, na = False, case=False, regex=True))]
                    
    print("There are {} questions.".format(len(new_df)))
    return new_df

# %%
# search questions that include 'King'
new_df = find_question(df, ['King'])
# Out:
# There are 1786 questions.

# %%
# find most common answer
from collections import Counter
 
def most_frequent(List):
    occurence_count = Counter(List)
    return occurence_count.most_common(1)[0][0]

print("The most common answer is: {}.".format(most_frequent(new_df['Answer'])))
# Out:
# The most common answer is: Henry VIII.

# %% [markdown]
# __Codecademy's Solution__

# %%
# A function to find the unique answers of a set of data
def get_answer_counts(data):
    return data["Answer"].value_counts()


# Testing the answer count function
print(get_answer_counts(filtered))
# Out:
# William the Conqueror       6
# Wessex                      3
# Richard the Lionhearted     3
# Henry VIII                  3
# George III                  3
#                            ..
# The Magna Carta             1
# King Hussein                1
# Charles                     1
# (Sir Edward) Elgar          1
# William of Orange roughy    1
# Name: Answer, Length: 114, dtype: int64

# %% [markdown]
# __7\.__ Explore from here! This is an incredibly rich dataset, and there are so many interesting things to discover. There are a few columns that we haven’t even started looking at yet. Here are some ideas on ways to continue working with this data:
#
# Investigate the ways in which questions change over time by filtering by the date. How many questions from the 90s use the word "Computer" compared to questions from the 2000s?

# %% [markdown]
# Is there a connection between the round and the category? Are you more likely to find certain categories, like "Literature" in Single Jeopardy or Double Jeopardy?

# %% [markdown]
# Build a system to quiz yourself. Grab random questions, and use the input function to get a response from the user. Check to see if that response was right or wrong. Note that you can’t do this on the Codecademy platform — to do this, download the data, and write and run the code on your own computer!

# %% [markdown]
# Is there a connection between the round and the category? Are you more likely to find certain categories, like "Literature" in Single Jeopardy or Double Jeopardy?
