# %%
import requests
import urllib.request
import time
import re
from bs4 import BeautifulSoup

# %%
url = 'https://stackoverflow.com/?tab=month'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
a_tags = soup.find(id='question-mini-list')
a_tags
# Out:
# <div id="question-mini-list">
# <div>
# <div class="s-post-summary js-post-summary" data-post-id="71387267" data-post-type-id="1" id="question-summary-71387267">
# <div class="s-post-summary--stats js-post-summary-stats">
# <div class="s-post-summary--stats-item s-post-summary--stats-item__emphasized" title="Score of 45">
# <span class="s-post-summary--stats-item-number mr4">45</span><span class="s-post-summary--stats-item-unit">votes</span>
# </div>
# <div class="s-post-summary--stats-item has-answers has-accepted-answer" title="one of the answers was accepted as the correct answer">
# <svg aria-hidden="true" class="svg-icon iconCheckmarkSm" height="14" viewbox="0 0 14 14" width="14"><path d="M13 3.41 11.59 2 5 8.59 2.41 6 1 7.41l4 4 8-8Z"></path></svg> <span class="s-post-summary--stats-item-number mr4">8</span><span class="s-post-summary--stats-item-unit">answers</span>
# </div>
# <div class="s-post-summary--stats-item is-warm" title="5201 views">
# ...

# %%
title = a_tags.find_all('div', class_='s-link')
title
# Out:
# []

# %%
m = re.findall(r'.*How do purely.*', str(a_tags))
m
# Out:
# ['            Month</a>, <a class="s-link" href="/questions/71387267/how-do-purely-functional-languages-handle-index-based-algorithms">How do purely functional languages handle index-based algorithms?</a>, <a class="post-tag flex--item mt0 js-tagname-haskell" href="/questions/tagged/haskell" rel="tag" title="show questions tagged \'haskell\'">haskell</a>, <a class="post-tag flex--item mt0 js-tagname-functional-programming" href="/questions/tagged/functional-programming" rel="tag" title="show questions tagged \'functional-programming\'">functional-programming</a>, <a class="post-tag flex--item mt0 js-tagname-lisp" href="/questions/tagged/lisp" rel="tag" title="show questions tagged \'lisp\'">lisp</a>, <a class="s-avatar s-avatar__16 s-user-card--avatar" href="/users/18377053/user18377053"> <div class="gravatar-wrapper-16" data-user-id="18377053">']
